# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = None

# %%
cols = ['RecordID', 'ESS_Id', 'EventTimeStamp', 'eventDescription', 'ecuSource', 'spn', 'fmi', 'active', 'activeTransitionCount',
           'EquipmentID', 'Latitude', 'Longitude']

faults = pd.read_csv("../data/J1939Faults.csv", usecols = cols, dtype = str)
faults.head()
# Out:
#   RecordID  ESS_Id           EventTimeStamp  \
# 0        1  990349  2015-02-21 10:47:13.000
# 1        2  990360  2015-02-21 11:34:34.000
# 2        3  990364  2015-02-21 11:35:31.000
# 3        4  990370  2015-02-21 11:35:33.000
# 4        5  990416  2015-02-21 11:39:41.000
#
#                           eventDescription ecuSource   spn fmi active  \
# 0  Low (Severity Low) Engine Coolant Level         0   111  17   True
# 1                                      NaN        11   629  12   True
# 2      Incorrect Data Steering Wheel Angle        11  1807   2  False
# 3      Incorrect Data Steering Wheel Angle        11  1807   2   True
# 4                                      NaN         0  4364  17  False
#
#   activeTransitionCount EquipmentID   Latitude   Longitude
# 0                     2        1439  38.857638  -84.626851
# 1                   127        1439  38.857638  -84.626851
# 2                   127        1369   41.42125  -87.767361
# 3                   127        1369  41.421018  -87.767361
# 4                     2        1674  38.416481  -89.442638

# %%
# convert dtypes as needed
# some columns have numeric-appearing values but they're not continuous variables, leaving them as strings
faults['EventTimeStamp'] = pd.to_datetime(faults['EventTimeStamp'])
faults['activeTransitionCount'] = faults['activeTransitionCount'].astype(int)

# %%
# time of day for faults could be interesting, split event column to date and timestamp columns
faults['event_date'] = faults['EventTimeStamp'].dt.date
faults['event_time'] = faults['EventTimeStamp'].dt.time

# %%
# sort df by equipment, spn, timestamp
faults = faults.copy()
faults = faults.sort_values(by = ['EquipmentID', 'spn', 'EventTimeStamp'])

# get index for first row in each group, yields list of integers
first_index = faults.groupby(['EquipmentID', 'spn']).head(1).index

# check first_index for rows where active == False
drop_index = first_index[faults.loc[first_index, 'active'] == 'False']

# drop rows where first index is an active False row
faults = faults.drop(drop_index)

# now this should work as expected
faults['false_eventTimeStamp'] = faults.sort_values(by = ['EventTimeStamp']).groupby(by = ['EquipmentID', 'spn'])['EventTimeStamp'].shift(-1)

# %%
# test to reveal if the process worked (this group previously had a False as the first timestamp)
faults.loc[(faults['EquipmentID'] == '1369') & (faults['spn'] == '1807')].sort_values(by = ['EventTimeStamp'])
# Out:
#      RecordID   ESS_Id      EventTimeStamp  \
# 3           4   990370 2015-02-21 11:35:33
# 31         32   990702 2015-02-21 11:57:37
# 49         50   990999 2015-02-21 12:13:47
# 421       422   995975 2015-02-21 18:26:34
# 422       423   995979 2015-02-21 18:26:37
# ...       ...      ...                 ...
# 6426     6427  1088496 2015-02-26 12:14:25
# 6434     6435  1089226 2015-02-26 13:00:12
# 6437     6438  1089547 2015-02-26 13:11:23
# 6492     6493  1094483 2015-02-26 16:05:38
# 6493     6494  1094496 2015-02-26 16:05:41
#
#                          eventDescription ecuSource   spn fmi active  \
# 3     Incorrect Data Steering Wheel Angle        11  1807   2   True
# 31    Incorrect Data Steering Wheel Angle        11  1807   2  False
# 49    Incorrect Data Steering Wheel Angle        11  1807   2   True
# 421   Incorrect Data Steering Wheel Angle        11  1807   2  False
# 422   Incorrect Data Steering Wheel Angle        11  1807   2   True
# ...                                   ...       ...   ...  ..    ...
# 6426  Incorrect Data Steering Wheel Angle        11  1807   2   True
# 6434  Incorrect Data Steering Wheel Angle        11  1807   2  False
# 6437  Incorrect Data Steering Wheel Angle        11  1807   2   True
# 6492  Incorrect Data Steering Wheel Angle        11  1807   2  False
# 6493  Incorrect Data Steering Wheel Angle        11  1807   2   True
#
#       activeTransitionCount EquipmentID            Latitude  \
# 3                       127        1369           41.421018
# 31                      127        1369            41.42787
# 49                      127        1369           41.431574
# 421                     127        1369           38.330833
# 422                     127        1369           38.330833
# ...                     ...         ...                 ...
# 6426                    127        1369           36.936018
# 6434                    127        1369  36.717453000000006
# 6437                    127        1369           36.718148
# 6492                    127        1369           35.679212
# 6493                    127        1369           35.679074
#
#                Longitude  event_date event_time false_eventTimeStamp
# 3             -87.767361  2015-02-21   11:35:33  2015-02-21 11:57:37
# 31            -87.756759  2015-02-21   11:57:37  2015-02-21 12:13:47
# 49            -87.758981  2015-02-21   12:13:47  2015-02-21 18:26:34
# 421           -85.757037  2015-02-21   18:26:34  2015-02-21 18:26:37
# 422           -85.757083  2015-02-21   18:26:37  2015-02-21 18:32:35
# ...                  ...         ...        ...                  ...
# 6426  -86.50726800000001  2015-02-26   12:14:25  2015-02-26 13:00:12
# 6434             -86.525  2015-02-26   13:00:12  2015-02-26 13:11:23
# 6437          -86.525324  2015-02-26   13:11:23  2015-02-26 16:05:38
# 6492          -88.745046  2015-02-26   16:05:38  2015-02-26 16:05:41
# 6493          -88.744675  2015-02-26   16:05:41                  NaT
#
# [108 rows x 15 columns]

# %%
# mask for each service station, lat and long to 2 decimal places
station_1 = (faults['Latitude'].str.contains('36.06')) & (faults['Longitude'].str.contains('86.43'))
station_2 = (faults['Latitude'].str.contains('35.58')) & (faults['Longitude'].str.contains('86.44'))
station_3 = (faults['Latitude'].str.contains('36.19')) & (faults['Longitude'].str.contains('83.17'))

# dataframe without faults associated with service locations
faults_nonservice = faults[~(station_1 | station_2 | station_3)]

# %% [markdown]
# ### next steps
# - add date and time breakout columns (year, month, date, weekday, hour, day segment (divide 24 hours into quadrants))
# - merge diagnostic data with filtered faults data (inner join)
# - figure out imputing methods
# - for models, imput after train/test split
# - do some eda on the data

# %%
faults_nonservice = faults_nonservice.copy()

faults_nonservice['event_year'] = faults_nonservice['EventTimeStamp'].dt.year
faults_nonservice['event_month'] = faults_nonservice['EventTimeStamp'].dt.month
faults_nonservice['event_day'] = faults_nonservice['EventTimeStamp'].dt.day
faults_nonservice['event_dayofweek'] = faults_nonservice['EventTimeStamp'].dt.dayofweek
faults_nonservice['event_dayname'] = faults_nonservice['EventTimeStamp'].dt.day_name()
faults_nonservice['event_hour'] = faults_nonservice['EventTimeStamp'].dt.hour
faults_nonservice['event_time_quadrant'] = faults_nonservice['EventTimeStamp'].dt.hour // 4

# %%
# drop active == False (Kagon is keeping these rows so it will give us a good way to compare performance)
faults_active = faults_nonservice.loc[faults_nonservice['active'] == 'True']

# %%
# for each equipment id that experienced a derate, durration of time before derate for each fault
# complicated by equipment that has more than one derate event
# derates can occur at any time of day (tend to be clustered during working hours bet that's probably because there are more trucks active) so don't want to just group by day
# just to get something working, go on date for now
faults_active = faults_active.copy()
faults_active['derate_full'] = np.where(faults_active.groupby(['EquipmentID', 'event_date'])['spn'].transform(lambda x: (x == '5246').any()), 'True', 'False')
faults_active['derate_partial'] = np.where(faults_active.groupby(['EquipmentID', 'event_date'])['spn'].transform(lambda x: (x == '1569').any()), 'True', 'False')

# come back to this later when my brain works
# faults_active['derates_all'] = np.where(faults_active.groupby(['EquipmentID', 'event_date'])['spn'].transform(lambda x: (x == '5246').any()), 'True', 'False')

# once we get how to calculate time of event before derate this code can be modified slightly to detect

# %%
# partial derate occurring on the same day as a full derate - incorporate this as a signal boost?
# come back to this after initial model
faults_active.loc[(faults_active['spn'] == '1569') & (faults_active['derate_full'] == 'True')]
# Out:
#         RecordID     ESS_Id      EventTimeStamp  \
# 996749   1032907   54267109 2018-07-06 04:53:05
# 5714        5715    1070647 2015-02-25 13:53:08
# 82873      85259    2919536 2015-06-12 08:24:15
# 82607      84993    2915364 2015-06-12 03:57:49
# 83619      86005    2932223 2015-06-12 19:26:10
# ...          ...        ...                 ...
# 1125718  1177138   93351982 2019-07-09 00:11:00
# 964660    995168   45003043 2018-04-07 02:07:44
# 794693    815232   18884125 2017-06-24 10:42:36
# 1139261  1192545  100080700 2019-08-30 18:05:29
# 1015548  1053642   60909415 2018-09-07 06:47:05
#
#                                          eventDescription ecuSource   spn fmi  \
# 996749   Condition Exists Engine Protection Torque Derate         0  1569  31
# 5714     Condition Exists Engine Protection Torque Derate         0  1569  31
# 82873    Condition Exists Engine Protection Torque Derate         0  1569  31
# 82607    Condition Exists Engine Protection Torque Derate         0  1569  31
# 83619    Condition Exists Engine Protection Torque Derate         0  1569  31
# ...                                                   ...       ...   ...  ..
# 1125718  Condition Exists Engine Protection Torque Derate         0  1569  31
# 964660   Condition Exists Engine Protection Torque Derate         0  1569  31
# 794693   Condition Exists Engine Protection Torque Derate         0  1569  31
# 1139261  Condition Exists Engine Protection Torque Derate         0  1569  31
# 1015548  Condition Exists Engine Protection Torque Derate         0  1569  31
#
#         active  activeTransitionCount EquipmentID  ... false_eventTimeStamp  \
# 996749    True                      2   105349576  ...  2018-07-10 15:44:13
# 5714      True                      1        1329  ...  2015-02-25 14:47:20
# 82873     True                      1        1339  ...  2015-06-14 15:56:28
# 82607     True                      1        1366  ...  2015-06-12 07:18:46
# 83619     True                      1        1366  ...  2015-06-12 20:49:02
# ...        ...                    ...         ...  ...                  ...
# 1125718   True                      1        1991  ...  2019-07-11 13:30:47
# 964660    True                      2        2007  ...  2018-04-07 09:45:39
# 794693    True                      1        2009  ...  2017-06-24 15:14:43
# 1139261   True                      1        2021  ...  2019-09-06 23:47:17
# 1015548   True                      1         306  ...  2018-09-09 15:03:53
#
#         event_year event_month event_day event_dayofweek  event_dayname  \
# 996749        2018           7         6               4         Friday
# 5714          2015           2        25               2      Wednesday
# 82873         2015           6        12               4         Friday
# 82607         2015           6        12               4         Friday
# 83619         2015           6        12               4         Friday
# ...            ...         ...       ...             ...            ...
# 1125718       2019           7         9               1        Tuesday
# 964660        2018           4         7               5       Saturday
# 794693        2017           6        24               5       Saturday
# 1139261       2019           8        30               4         Friday
# 1015548       2018           9         7               4         Friday
#
#          event_hour  event_time_quadrant  derate_full derate_partial
# 996749            4                    1         True           True
# 5714             13                    3         True           True
# 82873             8                    2         True           True
# 82607             3                    0         True           True
# 83619            19                    4         True           True
# ...             ...                  ...          ...            ...
# 1125718           0                    0         True           True
# 964660            2                    0         True           True
# 794693           10                    2         True           True
# 1139261          18                    4         True           True
# 1015548           6                    1         True           True
#
# [334 rows x 24 columns]

# %%
diagnostics = pd.read_csv('../data/VehicleDiagnosticOnboardData.csv')

# %%
# pivot on distinct values in 'Name'
diag_pivot = diagnostics.pivot(index = ['FaultId'], columns = ['Name'], values = ['Value'])
diag_pivot.columns = diag_pivot.columns.droplevel()

# %%
diag_pivot = diag_pivot.reset_index().rename_axis(None, axis = 1)

# %%
diag_pivot['FaultId'] = diag_pivot['FaultId'].astype(str)

# %%
# replace comma with period in all columns
diag_pivot = diag_pivot.replace(',', '.', regex = True)

# %%
# merge faults_active to diag_pivot on RecordID = FaultId
# how = left (keeps active True from faults and drops additional rows from diagnostics)
fault_diag = pd.merge(faults_active, diag_pivot, how = 'left', left_on = 'RecordID', right_on = 'FaultId')

# %%
fault_diag.isnull().sum()
# total rows ~550K
# rows that definitely don't have enough values to be useful: ServiceDistance, SwitchedBatteryVoltage
# extremely unlikely to be useful (1/3 to over half missing): FuelTemperature, ParkingBrake, Throttle
# iffy but possible to imput with some degree of meaning: FuelLevel, AcceleratorPedal
# quite a few are around 20-30K missing values
# Out:
# RecordID                          0
# ESS_Id                            0
# EventTimeStamp                    0
# eventDescription              29996
# ecuSource                         0
# spn                               0
# fmi                               0
# active                            0
# activeTransitionCount             0
# EquipmentID                       0
# Latitude                          0
# Longitude                         0
# event_date                        0
# event_time                        0
# false_eventTimeStamp            934
# event_year                        0
# event_month                       0
# event_day                         0
# event_dayofweek                   0
# event_dayname                     0
# event_hour                        0
# event_time_quadrant               0
# derate_full                       0
# derate_partial                    0
# FaultId                           0
# AcceleratorPedal              68105
# BarometricPressure            17752
# CruiseControlActive           27913
# CruiseControlSetSpeed         26855
# DistanceLtd                   17894
# EngineCoolantTemperature      17765
# EngineLoad                    18233
# EngineOilPressure             17646
# EngineOilTemperature          19284
# EngineRpm                     17330
# EngineTimeLtd                 21617
# FuelLevel                     93320
# FuelLtd                       18299
# FuelRate                      18503
# FuelTemperature              278071
# IgnStatus                         0
# IntakeManifoldTemperature     17659
# LampStatus                        0
# ParkingBrake                 195058
# ServiceDistance              549509
# Speed                         19376
# SwitchedBatteryVoltage       443253
# Throttle                     173538
# TurboBoostPressure            19851
# dtype: int64

# %%
# drop columns that are unlikely to be meaningful
fault_diag = fault_diag.drop(['ServiceDistance', 'SwitchedBatteryVoltage', 'ParkingBrake', 'FaultId'], axis = 1)

# %%
# convert data types
# add more as the need arises
convert_dict = {'AcceleratorPedal' : float,
                'BarometricPressure' : float,
                'CruiseControlSetSpeed' : float,
                'DistanceLtd' : float,
                'EngineCoolantTemperature': float,
                'EngineLoad' : float,
                'EngineOilPressure' : float,
                'EngineOilTemperature': float,
                'EngineRpm': float,
                'EngineTimeLtd': float,
                'FuelLevel' : float,
                'FuelLtd' : float,
                'FuelRate' : float,
                'FuelTemperature' : float,
                'IntakeManifoldTemperature' : float,
                #'LampStatus' : float,
                'Speed' : float,
                'Throttle' : float,
                'TurboBoostPressure' : float}

fault_diag = fault_diag.astype(convert_dict)

# %%
fault_diag.head(20)
# Out:
#    RecordID    ESS_Id      EventTimeStamp  \
# 0   1038243  55748536 2018-07-20 09:31:33
# 1    366301   7171498 2016-01-31 07:12:25
# 2   1141606  81618595 2019-03-27 08:10:52
# 3   1142275  81843663 2019-03-29 06:08:56
# 4   1149647  83749925 2019-04-16 12:27:33
# 5   1149942  83828217 2019-04-17 07:28:55
# 6   1151355  84239911 2019-04-21 10:20:25
# 7   1039465  56177839 2018-07-24 22:25:59
# 8   1039485  56179492 2018-07-24 23:06:41
# 9   1088428  70080023 2018-12-02 23:53:13
# 10  1039664  56206893 2018-07-25 07:53:53
# 11  1039702  56212638 2018-07-25 08:39:53
# 12  1088427  70080022 2018-12-02 23:53:10
# 13  1039463  56177837 2018-07-24 22:25:56
# 14  1039484  56179491 2018-07-24 23:06:38
# 15  1088426  70080021 2018-12-02 23:53:10
# 16  1134321  79583900 2019-03-07 16:48:19
# 17  1134343  79588166 2019-03-07 17:43:08
# 18  1141632  81625125 2019-03-27 08:44:21
# 19  1039480  56179054 2018-07-24 22:50:46
#
#                                      eventDescription ecuSource   spn fmi  \
# 0             High (Severity Medium) J1939 Network #2        49  1231  16
# 1                                                 NaN        11   629  12
# 2          Low (Severity Medium) Engine Coolant Level         0   111  18
# 3          Low (Severity Medium) Engine Coolant Level         0   111  18
# 4          Low (Severity Medium) Engine Coolant Level         0   111  18
# 5          Low (Severity Medium) Engine Coolant Level         0   111  18
# 6          Low (Severity Medium) Engine Coolant Level         0   111  18
# 7                 Abnormal Frequency J1939 Network #2        49  1231   8
# 8                 Abnormal Frequency J1939 Network #2        49  1231   8
# 9                 Abnormal Frequency J1939 Network #2        49  1231   8
# 10  Abnormal Update Rate Source Address of Control...        49  1482   9
# 11  Abnormal Update Rate Source Address of Control...        49  1482   9
# 12  Abnormal Update Rate Source Address of Control...        49  1482   9
# 13  Abnormal Update Rate Source Address of Control...        49  1483   9
# 14  Abnormal Update Rate Source Address of Control...        49  1483   9
# 15  Abnormal Update Rate Source Address of Control...        49  1483   9
# 16                 Incorrect Data Engine Starter Mode        49  1675   2
# 17                 Incorrect Data Engine Starter Mode        49  1675   2
# 18                 Incorrect Data Engine Starter Mode        49  1675   2
# 19             Incorrect Data Ambient Air Temperature        49   171   2
#
#    active  activeTransitionCount EquipmentID            Latitude  \
# 0    True                      2  0105406655           36.139351
# 1    True                    127   105301976           41.987175
# 2    True                      1   105338729           36.060324
# 3    True                      3   105338729  34.410509000000005
# 4    True                      4   105338729           36.142083
# 5    True                      5   105338729           37.774351
# 6    True                      6   105338729           37.875833
# 7    True                      4   105338729  41.483796000000005
# 8    True                      6   105338729  41.483934999999995
# 9    True                      7   105338729           32.806759
# 10   True                     22   105338729  41.484165999999995
# 11   True                     33   105338729  41.484120000000004
# 12   True                     36   105338729           32.806759
# 13   True                      4   105338729  41.483796000000005
# 14   True                      6   105338729  41.483934999999995
# 15   True                      7   105338729           32.806759
# 16   True                      1   105338729           35.781759
# 17   True                      3   105338729           35.781759
# 18   True                      4   105338729           36.058703
# 19   True                      1   105338729  41.484027000000005
#
#              Longitude  event_date event_time false_eventTimeStamp  \
# 0           -85.629722  2018-07-20   09:31:33  2018-07-20 09:42:30
# 1            -87.73199  2016-01-31   07:12:25                  NaT
# 2           -87.351435  2019-03-27   08:10:52  2019-03-27 08:12:58
# 3            -84.91824  2019-03-29   06:08:56  2019-03-29 06:12:07
# 4           -85.365833  2019-04-16   12:27:33  2019-04-16 12:29:35
# 5           -87.098148  2019-04-17   07:28:55  2019-04-17 07:30:51
# 6           -79.308194  2019-04-21   10:20:25  2019-04-21 10:23:04
# 7           -88.179259  2018-07-24   22:25:59  2018-07-24 22:35:12
# 8           -88.179351  2018-07-24   23:06:41  2018-07-24 23:22:13
# 9           -96.886157  2018-12-02   23:53:13  2018-12-02 23:57:31
# 10  -88.17916600000001  2018-07-25   07:53:53  2018-07-25 08:05:52
# 11          -88.179074  2018-07-25   08:39:53  2018-07-25 09:05:40
# 12          -96.886157  2018-12-02   23:53:10  2018-12-02 23:57:31
# 13          -88.179259  2018-07-24   22:25:56  2018-07-24 22:35:12
# 14          -88.179351  2018-07-24   23:06:38  2018-07-24 23:22:13
# 15          -96.886157  2018-12-02   23:53:10  2018-12-02 23:57:31
# 16  -86.40208299999999  2019-03-07   16:48:19  2019-03-07 17:26:16
# 17          -86.402129  2019-03-07   17:43:08  2019-03-07 18:25:58
# 18          -87.347037  2019-03-27   08:44:21  2019-03-27 08:52:57
# 19           -88.17949  2018-07-24   22:50:46  2018-07-24 23:03:11
#
#     event_year  event_month  event_day  event_dayofweek event_dayname  \
# 0         2018            7         20                4        Friday
# 1         2016            1         31                6        Sunday
# 2         2019            3         27                2     Wednesday
# 3         2019            3         29                4        Friday
# 4         2019            4         16                1       Tuesday
# 5         2019            4         17                2     Wednesday
# 6         2019            4         21                6        Sunday
# 7         2018            7         24                1       Tuesday
# 8         2018            7         24                1       Tuesday
# 9         2018           12          2                6        Sunday
# 10        2018            7         25                2     Wednesday
# 11        2018            7         25                2     Wednesday
# 12        2018           12          2                6        Sunday
# 13        2018            7         24                1       Tuesday
# 14        2018            7         24                1       Tuesday
# 15        2018           12          2                6        Sunday
# 16        2019            3          7                3      Thursday
# 17        2019            3          7                3      Thursday
# 18        2019            3         27                2     Wednesday
# 19        2018            7         24                1       Tuesday
#
#     event_hour  event_time_quadrant derate_full derate_partial  \
# 0            9                    2       False          False
# 1            7                    1       False          False
# 2            8                    2       False          False
# 3            6                    1       False          False
# 4           12                    3       False          False
# 5            7                    1       False          False
# 6           10                    2       False          False
# 7           22                    5       False          False
# 8           23                    5       False          False
# 9           23                    5       False          False
# 10           7                    1       False          False
# 11           8                    2       False          False
# 12          23                    5       False          False
# 13          22                    5       False          False
# 14          23                    5       False          False
# 15          23                    5       False          False
# 16          16                    4       False          False
# 17          17                    4       False          False
# 18           8                    2       False          False
# 19          22                    5       False          False
#
#     AcceleratorPedal  BarometricPressure CruiseControlActive  \
# 0               24.0             14.1375               False
# 1                NaN                 NaN                 NaN
# 2                0.0             14.4275               False
# 3                0.0             14.3550               False
# 4               16.4             13.9200               False
# 5                0.0             14.4275               False
# 6                0.0             13.7750               False
# 7                0.0             14.3550               False
# 8                0.0             14.3550               False
# 9                NaN                 NaN                 NaN
# 10               0.0             14.4275               False
# 11               0.0             14.4275               False
# 12               NaN                 NaN                 NaN
# 13               0.0             14.3550               False
# 14               0.0             14.3550               False
# 15               NaN                 NaN                 NaN
# 16               0.0             14.4275               False
# 17              98.8             14.4275               False
# 18               0.0             14.4275               False
# 19               NaN                 NaN                 NaN
#
#     CruiseControlSetSpeed  DistanceLtd  EngineCoolantTemperature  EngineLoad  \
# 0                     0.0     91442.55                     181.4        12.0
# 1                     NaN          NaN                       NaN         NaN
# 2                     0.0    112671.80                      71.6        23.0
# 3                     0.0    113623.20                      84.2        25.0
# 4                     0.0    119095.80                     179.6         0.0
# 5                     0.0    119346.50                      86.0        25.0
# 6                     0.0    120430.70                      60.8        28.0
# 7                     0.0     52169.60                     120.2         0.0
# 8                     0.0     52169.60                     113.0         0.0
# 9                     NaN          NaN                       NaN         NaN
# 10                    0.0     52169.70                     138.2         0.0
# 11                    0.0     52169.70                     129.2         0.0
# 12                    NaN     91467.32                       NaN         NaN
# 13                    0.0     52169.60                     120.2         0.0
# 14                    0.0     52169.60                     113.0         0.0
# 15                    NaN     91467.32                       NaN         NaN
# 16                    0.0    107062.80                     186.8         0.0
# 17                    0.0    107062.80                     168.8         0.0
# 18                    0.0    112672.10                     129.2         0.0
# 19                    NaN          NaN                       NaN         NaN
#
#     EngineOilPressure  EngineOilTemperature  EngineRpm  EngineTimeLtd  \
# 0               39.44             203.73120   1144.375        1703.05
# 1                 NaN                   NaN        NaN            NaN
# 2               44.66              57.70625    601.625        2838.15
# 3               42.34              81.78125    600.125        2859.90
# 4               39.44             226.40000   1227.500        2981.55
# 5               41.76              86.39375    601.500        2988.70
# 6               45.82              53.09375    700.500        3013.95
# 7                0.00             119.75000      0.000        1202.10
# 8                0.00             114.23750      0.000        1202.10
# 9                 NaN                   NaN        NaN        2195.35
# 10               0.00             139.60620      0.000        1202.45
# 11               0.00             131.33750      0.000        1202.45
# 12                NaN                   NaN        NaN        2195.35
# 13               0.00             119.75000      0.000        1202.10
# 14               0.00             114.23750      0.000        1202.10
# 15                NaN                   NaN        NaN        2195.35
# 16               0.00             189.83750      0.000        2618.30
# 17               0.00             164.07500      0.000        2618.30
# 18               0.00             132.74370      0.000        2838.60
# 19                NaN                   NaN        NaN            NaN
#
#     FuelLevel       FuelLtd  FuelRate  FuelTemperature IgnStatus  \
# 0         NaN  12311.606397  1.651080              NaN      True
# 1         NaN           NaN       NaN              NaN      True
# 2        44.0  14987.537198  1.083109              NaN      True
# 3        52.8  15098.753632  0.990648              NaN      True
# 4        62.0  15782.959247  0.039626              NaN      True
# 5        48.4  15809.508538  0.977440              NaN      True
# 6       100.0  15969.993060  1.875627              NaN      True
# 7        87.6   7162.232674  0.000000              NaN      True
# 8        87.6   7162.232674  0.000000              NaN      True
# 9        49.6  12247.016331       NaN              NaN      True
# 10       84.4   7162.496846  0.000000              NaN      True
# 11       84.4   7162.496846  0.000000              NaN      True
# 12       49.6  12247.016331       NaN              NaN      True
# 13       87.6   7162.232674  0.000000              NaN      True
# 14       87.6   7162.232674  0.000000              NaN      True
# 15       49.6  12247.016331       NaN              NaN      True
# 16       75.2  14233.590162  0.000000              NaN      True
# 17       75.2  14233.590162  0.000000              NaN      True
# 18       40.4  14988.065542  0.000000              NaN      True
# 19       87.6           NaN       NaN              NaN      True
#
#     IntakeManifoldTemperature  LampStatus      Speed  Throttle  \
# 0                       138.2       255.0   5.203984     100.0
# 1                         NaN      1279.0        NaN       NaN
# 2                        59.0      2047.0   0.000000     100.0
# 3                        73.4      2047.0   0.000000     100.0
# 4                        95.0      2047.0  67.525570     100.0
# 5                        82.4      2047.0   0.000000     100.0
# 6                        57.2      2047.0   0.000000     100.0
# 7                       107.6      1279.0   0.000000     100.0
# 8                       102.2      1279.0   0.000000     100.0
# 9                         NaN      1279.0        NaN       NaN
# 10                      111.2      1279.0   0.000000     100.0
# 11                      113.0      1279.0   0.000000     100.0
# 12                        NaN      1279.0        NaN       NaN
# 13                      107.6      1279.0   0.000000     100.0
# 14                      102.2      1279.0   0.000000     100.0
# 15                        NaN      1279.0        NaN       NaN
# 16                      118.4      1279.0   0.000000     100.0
# 17                      136.4      1279.0   0.000000     100.0
# 18                       89.6      1279.0   0.000000     100.0
# 19                        NaN      1279.0        NaN       NaN
#
#     TurboBoostPressure  spn_fmi EngineCoolantTemperature_cat EngineLoad_cat  \
# 0                 5.80  1231_16                          low           high
# 1                  NaN   629_12                          NaN            NaN
# 2                 0.29   111_18                          low           high
# 3                 0.00   111_18                          low           high
# 4                 3.48   111_18                          low            low
# 5                 0.00   111_18                          low           high
# 6                 0.87   111_18                          low           high
# 7                 0.00   1231_8                          low            low
# 8                 0.00   1231_8                          low            low
# 9                  NaN   1231_8                          NaN            NaN
# 10                0.00   1482_9                          low            low
# 11                0.00   1482_9                          low            low
# 12                 NaN   1482_9                          NaN            NaN
# 13                0.00   1483_9                          low            low
# 14                0.00   1483_9                          low            low
# 15                 NaN   1483_9                          NaN            NaN
# 16                0.00   1675_2                          low            low
# 17                0.00   1675_2                          low            low
# 18                0.00   1675_2                          low            low
# 19                 NaN    171_2                          NaN            NaN
#
#    EngineOilPressure_cat EngineOilTemperature_cat EngineRpm_cat FuelRate_cat  \
# 0                   high                     high          high          low
# 1                    NaN                      NaN           NaN          NaN
# 2                   high                     high          high          low
# 3                   high                     high          high          low
# 4                   high                     high          high          low
# 5                   high                     high          high          low
# 6                   high                     high          high          low
# 7                    low                     high           low          low
# 8                    low                     high           low          low
# 9                    NaN                      NaN           NaN          NaN
# 10                   low                     high           low          low
# 11                   low                     high           low          low
# 12                   NaN                      NaN           NaN          NaN
# 13                   low                     high           low          low
# 14                   low                     high           low          low
# 15                   NaN                      NaN           NaN          NaN
# 16                   low                     high           low          low
# 17                   low                     high           low          low
# 18                   low                     high           low          low
# 19                   NaN                      NaN           NaN          NaN
#
#    FuelTemperature_cat IntakeManifoldTemperature_cat TurboBoostPressure_cat
# 0                  NaN                          high                    low
# 1                  NaN                           NaN                    NaN
# 2                  NaN                           low                    low
# 3                  NaN                        normal                    low
# 4                  NaN                          high                    low
# 5                  NaN                        normal                    low
# 6                  NaN                           low                    low
# 7                  NaN                          high                    low
# 8                  NaN                          high                    low
# 9                  NaN                           NaN                    NaN
# 10                 NaN                          high                    low
# 11                 NaN                          high                    low
# 12                 NaN                           NaN                    NaN
# 13                 NaN                          high                    low
# 14                 NaN                          high                    low
# 15                 NaN                           NaN                    NaN
# 16                 NaN                          high                    low
# 17                 NaN                          high                    low
# 18                 NaN                        normal                    low
# 19                 NaN                           NaN                    NaN

# %%
# adding a concat column for spn and fmi
fault_diag['spn_fmi'] = fault_diag['spn'] + '_' + fault_diag['fmi']

# %% [markdown]
# Rob's idea to categorize diagnostics based on normal operating parameters, so categorical column with low, normal, high.
# To implement: dictionary with diagnostic name as key and tuple or list of lower and upper limits of normal range
# Loop through dictionary, create new column name based on diagnostic and assign low if below lower limit, normal if below upper limit, else high.

# %%
# replace with real operating parameters
diag_cols = {#'AcceleratorPedal' : [5, 10],
                #'BarometricPressure' : [5, 10],
                #'CruiseControlSetSpeed' : [5, 10],
                #'DistanceLtd' : [5, 10],
                'EngineCoolantTemperature': [180, 220],
                #'EngineLoad' : [5, 10], #this is % of laod at that moment of potential engine can make
                'EngineOilPressure' : [35, 50],
                'EngineOilTemperature': [180, 240],
                'EngineRpm': [1400, 1900],
                #'EngineTimeLtd': [5, 10],
                #'FuelLevel' : [5, 10],
                #'FuelLtd' : [5, 10],
                #'FuelRate' : [5, 10],
                'FuelTemperature' : [180, 10],
                'IntakeManifoldTemperature' : [60, 90],
                #'LampStatus' : [5, 10],
                #'Speed' : [5, 10],
                #'Throttle' : [5, 10],
                'TurboBoostPressure' : [36, 44]}

# %%
for col, bounds in diag_cols.items():
    low_bound, high_bound = bounds
    new_col = f'{col}_cat'
    fault_diag[new_col] = pd.cut(fault_diag[col], bins = [-float('inf'), low_bound, high_bound, float('inf')], labels = ['low', 'normal', 'high'])

# %%
fault_diag.head()
# Out:
#   RecordID    ESS_Id      EventTimeStamp  \
# 0  1038243  55748536 2018-07-20 09:31:33
# 1   366301   7171498 2016-01-31 07:12:25
# 2  1141606  81618595 2019-03-27 08:10:52
# 3  1142275  81843663 2019-03-29 06:08:56
# 4  1149647  83749925 2019-04-16 12:27:33
#
#                              eventDescription ecuSource   spn fmi active  \
# 0     High (Severity Medium) J1939 Network #2        49  1231  16   True
# 1                                         NaN        11   629  12   True
# 2  Low (Severity Medium) Engine Coolant Level         0   111  18   True
# 3  Low (Severity Medium) Engine Coolant Level         0   111  18   True
# 4  Low (Severity Medium) Engine Coolant Level         0   111  18   True
#
#    activeTransitionCount EquipmentID            Latitude   Longitude  \
# 0                      2  0105406655           36.139351  -85.629722
# 1                    127   105301976           41.987175   -87.73199
# 2                      1   105338729           36.060324  -87.351435
# 3                      3   105338729  34.410509000000005   -84.91824
# 4                      4   105338729           36.142083  -85.365833
#
#    event_date event_time false_eventTimeStamp  event_year  event_month  \
# 0  2018-07-20   09:31:33  2018-07-20 09:42:30        2018            7
# 1  2016-01-31   07:12:25                  NaT        2016            1
# 2  2019-03-27   08:10:52  2019-03-27 08:12:58        2019            3
# 3  2019-03-29   06:08:56  2019-03-29 06:12:07        2019            3
# 4  2019-04-16   12:27:33  2019-04-16 12:29:35        2019            4
#
#    event_day  event_dayofweek event_dayname  event_hour  event_time_quadrant  \
# 0         20                4        Friday           9                    2
# 1         31                6        Sunday           7                    1
# 2         27                2     Wednesday           8                    2
# 3         29                4        Friday           6                    1
# 4         16                1       Tuesday          12                    3
#
#   derate_full derate_partial  AcceleratorPedal  BarometricPressure  \
# 0       False          False              24.0             14.1375
# 1       False          False               NaN                 NaN
# 2       False          False               0.0             14.4275
# 3       False          False               0.0             14.3550
# 4       False          False              16.4             13.9200
#
#   CruiseControlActive  CruiseControlSetSpeed  DistanceLtd  \
# 0               False                    0.0     91442.55
# 1                 NaN                    NaN          NaN
# 2               False                    0.0    112671.80
# 3               False                    0.0    113623.20
# 4               False                    0.0    119095.80
#
#    EngineCoolantTemperature  EngineLoad  EngineOilPressure  \
# 0                     181.4        12.0              39.44
# 1                       NaN         NaN                NaN
# 2                      71.6        23.0              44.66
# 3                      84.2        25.0              42.34
# 4                     179.6         0.0              39.44
#
#    EngineOilTemperature  EngineRpm  EngineTimeLtd  FuelLevel       FuelLtd  \
# 0             203.73120   1144.375        1703.05        NaN  12311.606397
# 1                   NaN        NaN            NaN        NaN           NaN
# 2              57.70625    601.625        2838.15       44.0  14987.537198
# 3              81.78125    600.125        2859.90       52.8  15098.753632
# 4             226.40000   1227.500        2981.55       62.0  15782.959247
#
#    FuelRate  FuelTemperature IgnStatus  IntakeManifoldTemperature  LampStatus  \
# 0  1.651080              NaN      True                      138.2       255.0
# 1       NaN              NaN      True                        NaN      1279.0
# 2  1.083109              NaN      True                       59.0      2047.0
# 3  0.990648              NaN      True                       73.4      2047.0
# 4  0.039626              NaN      True                       95.0      2047.0
#
#        Speed  Throttle  TurboBoostPressure  spn_fmi  \
# 0   5.203984     100.0                5.80  1231_16
# 1        NaN       NaN                 NaN   629_12
# 2   0.000000     100.0                0.29   111_18
# 3   0.000000     100.0                0.00   111_18
# 4  67.525570     100.0                3.48   111_18
#
#   EngineCoolantTemperature_cat EngineLoad_cat EngineOilPressure_cat  \
# 0                          low           high                  high
# 1                          NaN            NaN                   NaN
# 2                          low           high                  high
# 3                          low           high                  high
# 4                          low            low                  high
#
#   EngineOilTemperature_cat EngineRpm_cat FuelRate_cat FuelTemperature_cat  \
# 0                     high          high          low                 NaN
# 1                      NaN           NaN          NaN                 NaN
# 2                     high          high          low                 NaN
# 3                     high          high          low                 NaN
# 4                     high          high          low                 NaN
#
#   IntakeManifoldTemperature_cat TurboBoostPressure_cat
# 0                          high                    low
# 1                           NaN                    NaN
# 2                           low                    low
# 3                        normal                    low
# 4                          high                    low

# %%
fault_diag.to_csv('../data/fault_diag.csv', index = False)

# %% [markdown]
# ### target:
# - group by equipment ID and sort by event datetime
# - if equipment had derate (fault id) boolean column true for records within a certain timeframe prior
# - looking for a signal with enough time to get the truck to a service location
#
# ### predictors:
# - fault codes, diagnostics (downside is that a lot of values are missing, but they seem to be more present with active true)
# - might not be value in looking at active false (Tomo's group only looked at active true)
#
# ### do this as part of data cleaning:
# - pull timestamp from active false to get duration of active true (there should be paired rows based on fault code, different lights for different faults)
# - do this before dropping service locations (don't want to miss active false which happened as a result of service)
#
# ### other thoughts:
# - Code P0606 tends to be set when a PCM/ECM has failed. Depending on component condition and the make and model of a vehicle, it may be possible to resolve an internal integrity fault in the PCM/ECM by upgrading or re-flashing the control module.
# - since it's a fault with the monitoring device itself, might not have any predictive power
# - how many are there?
# - if we get rid of this (and other faults not actually related to the engine) might reduce noise in the dataset?
# - since there are active true with no diagnostics, could the rows with null diagnostics be faults like this one that don't have anything to do with the engine?
